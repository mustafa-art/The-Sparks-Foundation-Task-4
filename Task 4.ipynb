# %% [markdown]
# # Name: Mustafa Ahmed Hemdan
#
# ## Data Science and Business Analytics
#
# ## Perform 'Exploratory Data Analysis' on dataset 'Global Terrorism'

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns 
sns.set()

# %%
data = pd.read_csv('global terrorism.csv', encoding='cp1252', low_memory =False)

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.shape
# Out:
# (181691, 135)

# %%
pd.set_option('display.max_rows', None)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
# there's 135 columns i'll choose the one that got my intention 

new_data = data[['iyear', 'imonth', 'iday', 'country_txt', 'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'gname',
                'motive', 'attacktype1_txt', 'targtype1_txt', 'target1', 'weaptype1_txt', 'nkill', 'success', 'nwound']]

# %%
new_data.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city   latitude   longitude  \
# 0       NaN  Santo Domingo  18.456792  -69.951164
# 1   Federal    Mexico city  19.371887  -99.086624
# 2    Tarlac        Unknown  15.478598  120.599741
# 3    Attica         Athens  37.997490   23.762728
# 4   Fukouka        Fukouka  33.580412  130.396361
#
#                                 gname motive                 attacktype1_txt  \
# 0                              MANO-D    NaN                   Assassination
# ...

# %%
# rename columns 
new_data.rename(columns={'iyear':'Year', 'imonth':'Month', 'iday':'Day', 'country_txt':'Country', 'region_txt':'Region',
                   'provstate':'State', 'city':'City', 'latitude':'Latitude', 'longitude':'Longitude', 
                   'gname':'Group',  'motive':'Motive', 'attacktype1_txt':'Attack_Type', 
                   'targtype1_txt':'Target_Type', 'target1':'Target', 'weaptype1_txt':'Weapon_Type', 
                   'nkill':'Killed', 'success':'Success', 'nwound':'Wounded'}, inplace=True)
# Out:
# C:\Users\7emdan\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
new_data.head()
# Out:
#    Year  Month  Day             Country                       Region    State  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean      NaN
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             City   Latitude   Longitude                               Group  \
# 0  Santo Domingo  18.456792  -69.951164                              MANO-D
# 1    Mexico city  19.371887  -99.086624  23rd of September Communist League
# 2        Unknown  15.478598  120.599741                             Unknown
# 3         Athens  37.997490   23.762728                             Unknown
# 4        Fukouka  33.580412  130.396361                             Unknown
#
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   Region       181691 non-null  object
#  5   State        181270 non-null  object
#  6   City         181257 non-null  object
#  7   Latitude     177135 non-null  float64
#  8   Longitude    177134 non-null  float64
#  9   Group        181691 non-null  object
#  10  Motive       50561 non-null   object
#  11  Attack_Type  181691 non-null  object
#  12  Target_Type  181691 non-null  object
#  13  Target       181055 non-null  object
#  14  Weapon_Type  181691 non-null  object
#  15  Killed       171378 non-null  float64
#  16  Success      181691 non-null  int64
#  17  Wounded      165380 non-null  float64
# ...

# %%
new_data['Cases'] = new_data['Killed'] + new_data['Wounded']
# Out:
# <ipython-input-17-3bcaec1ea513>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['Cases'] = new_data['Killed'] + new_data['Wounded']

# %%
new_data.shape
# Out:
# (181691, 19)

# %%
new_data.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Success        Wounded  \
# count  1.771340e+05  171378.000000  181691.000000  165380.000000
# mean  -4.586957e+02       2.403272       0.889598       3.167668
# std    2.047790e+05      11.545741       0.313391      35.949392
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %%
new_data.head()
# Out:
#    Year  Month  Day             Country                       Region    State  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean      NaN
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             City   Latitude   Longitude                               Group  \
# 0  Santo Domingo  18.456792  -69.951164                              MANO-D
# 1    Mexico city  19.371887  -99.086624  23rd of September Communist League
# 2        Unknown  15.478598  120.599741                             Unknown
# 3         Athens  37.997490   23.762728                             Unknown
# 4        Fukouka  33.580412  130.396361                             Unknown
#
# ...

# %%
new_data['Region'].value_counts()
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Region, dtype: int64

# %%
x_region = new_data['Region'].value_counts().index
y_region = new_data['Region'].value_counts().values

plt.figure(figsize=(15,8))
sns.barplot(x=x_region, y=y_region)
plt.xticks(rotation=90)
plt.title('Most Region with terrorist attacks')
plt.xlabel('Region')
plt.ylabel('Cases Count')
plt.show()

# %% [markdown]
# - 'MiddleEast & NorthAfrica' and 'SouthAsia' are the 2 highest regions with terrorist attacks

# %%
# most 10 Countries with terrorist attacks
top_country_attacks = new_data['Country'].value_counts().head(10)
top_country_attacks
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
top_country_attacks.plot(kind='bar', figsize=(6,6))
plt.title('Top 10 country with Terrorist Attacks')
plt.xlabel('Country')
plt.ylabel('Attacks Count')
plt.show()

# %%
# most 10 Cities with terrorist attacks
new_data['City'].value_counts().head(10)
# Out:
# Unknown         9775
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Name: City, dtype: int64

# %%
# Most 10 terrorist groups 
top_groups = new_data['Group'].value_counts().head(10)
top_groups
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Name: Group, dtype: int64

# %%
# the top 10 terrorist groups 
top_groups[1:].plot(kind='bar', figsize=(6,6))
plt.title('Top Terrorist Groups')
plt.xlabel('Terrorist Group')
plt.ylabel('Attacks Count')
plt.show()

# %%
# go deeper into the Taliban Group since it's the most Terrorist gtoup for attacks 
taliban_group = new_data[new_data['Group']=='Taliban']
taliban_group.head()
# Out:
#        Year  Month  Day      Country      Region     State       City  \
# 59040  1995      4   20  Afghanistan  South Asia   Unknown    Unknown
# 60014  1995      8    3  Afghanistan  South Asia  Kandahar   Kandahar
# 60462  1995      9   21  Afghanistan  South Asia  Kandahar   Kandahar
# 60786  1995     10   25  Afghanistan  South Asia     Kabul      Kabul
# 71682  2001      1    7  Afghanistan  South Asia    Bamyan  Yakawlang
#
#         Latitude  Longitude    Group  \
# 59040        NaN        NaN  Taliban
# 60014  31.631083  65.742226  Taliban
# 60462  31.631083  65.742226  Taliban
# 60786  34.516895  69.147011  Taliban
# 71682  34.733333  66.966667  Taliban
#
#                                                   Motive  \
# 59040                                                NaN
# 60014                                                NaN
# 60462                                                NaN
# 60786                                                NaN
# ...

# %%
# The most Attack type used by the Taliban Group 
taliban_group['Attack_Type'].value_counts()
# Out:
# Bombing/Explosion                      2866
# Armed Assault                          2125
# Unknown                                 966
# Hostage Taking (Kidnapping)             713
# Assassination                           508
# Facility/Infrastructure Attack          235
# Unarmed Assault                          33
# Hostage Taking (Barricade Incident)      19
# Hijacking                                13
# Name: Attack_Type, dtype: int64

# %%
# The mst countries attacked by Taliban Group 
taliban_group['Country'].value_counts()
# Out:
# Afghanistan     7423
# Pakistan          54
# Turkmenistan       1
# Name: Country, dtype: int64

# %% [markdown]
# - Bombing /Explosion is the most attack type used by the Taliban Group, also almost all of the Taliban atacks happened in Afghanistan,
# - let's see if it has a specefic target

# %%
taliban_group['Target'].value_counts()
# Out:
# Checkpoint                                                                                                                                                                    577
# Vehicle                                                                                                                                                                       365
# Checkpost                                                                                                                                                                     334
# Civilians                                                                                                                                                                     333
# Unknown                                                                                                                                                                       295
# ...

# %%
taliban_group['Motive'].value_counts()
# Out:
# The specific motive for the attack is unknown.                                                                                                                                                                                                                                                                                                                                                                                               723
# Unknown                                                                                                                                                                                                                                                                                                                                                                                                                                      605
# ...

# %% [markdown]
# - Almost all of Afghanistans' buildings have suffered from the Taliban, also they killed mens, famillies, Children and women,
# - this is a group that has no particular motive, they just kill with a cold blood

# %%
new_data['Motive'].unique()
# Out:
# array([nan, 'To protest the Cairo Illinois Police Deparment',
#        'To protest the War in Vietnam and the draft', ...,
#        'The specific motive is unknown; however, sources stated that the attack was carried out in retaliation for the death of Noor Mohammad Tantray (Noor Trali), a Jaish-e-Mohammad (JeM) leader, by security personnel on December 26, 2017 in Pulwama.',
#        'The specific motive is unknown; however, sources noted that the targeted building housed migrants.',
#        'The specific motive is unknown; however, sources stated that the Taliban had warned one of the victims against collaborating with the government.'],
#       dtype=object)

# %%
# the most 20 years with biggest cases of injuries+kills with the group and city 
new_data.pivot_table(values='Cases', index=['Year', 'City','Group']).sort_values('Cases', ascending=False).head(20)
# Out:
#                                                                            Cases
# Year City             Group
# 2001 New York City    Al-Qaida                                            9574.0
# 1998 Nairobi          Al-Qaida                                            4224.0
# 1994 Gikoro           Hutu extremists                                     1180.0
# 1995 Tokyo            Aum Shinri Kyo                                      1103.4
# 2004 Beslan           Riyadus-Salikhin Reconnaissance and Sabotage Ba...  1071.0
# 2006 Mumbai           Lashkar-e-Taiba (LeT)                               1005.0
# 2007 Qahtaniya        Al-Qaida in Iraq                                    1000.0
#      Jazeera          Al-Qaida in Iraq                                    1000.0
# 2017 Las Vegas        Anti-Government extremists                           910.0
# 1995 Oklahoma City    Anti-Government extremists                           818.0
# ...

# %% [markdown]
# - the biggest attack happened in newyork city by AlQaida with around 9500 cases of injuries+kills

# %%
# let's count cases from terrorist attacks by year  
X= new_data.groupby('Year')['Cases'].sum().index

# %%
Y = new_data.groupby('Year')['Cases'].sum().values

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=X, y=Y)
plt.xticks(rotation=90)
plt.title('Number of cases by year from Terrorist attacks')
plt.xlabel('Year')
plt.ylabel('Cases Count')
plt.show()

# %% [markdown]
# - The year with the most cases of injuries+kills from terrorist attacks is 2015 with more than 70000 cases
# - we see that the curve is up and down for many times from 1980 to 2010 , in 2012 it increased alot with around 39000, cases and it's just the beginning let's go deeper

# %%
high_cases_years  = new_data[new_data['Year'] >= 2012]

# %%
high_cases_years.head()
# Out:
#         Year  Month  Day   Country              Region          State  \
# 104778  2012      1    1  Pakistan          South Asia    Balochistan
# 104779  2012      1    1     Kenya  Sub-Saharan Africa  North Eastern
# 104780  2012      1    1  Pakistan          South Asia    Balochistan
# 104781  2012      1    1     Kenya  Sub-Saharan Africa  North Eastern
# 104782  2012      1    1  Pakistan          South Asia    Balochistan
#
#                 City   Latitude  Longitude                         Group  \
# 104778        Quetta  30.200819  66.994354                       Unknown
# 104779       Garissa  -0.456120  39.646123                    Al-Shabaab
# 104780           Sui  28.633307  69.190369  Baloch Republican Army (BRA)
# 104781       Garissa  -0.456120  39.646123                    Al-Shabaab
# 104782  Peer Chhatta  28.466667  67.283333                       Unknown
#
#                                                    Motive  \
# ...

# %%
# let's see what groups were active at this period of time and remove the first group 'Unknown'
high_cases_years['Group'].value_counts()[1:]
# Out:
# Taliban                                                                       5818
# Islamic State of Iraq and the Levant (ISIL)                                   5613
# Al-Shabaab                                                                    2963
# Boko Haram                                                                    2266
# New People's Army (NPA)                                                       1437
# Maoists                                                                       1330
# Kurdistan Workers' Party (PKK)                                                1081
# Houthi extremists (Ansar Allah)                                               1048
# Al-Qaida in the Arabian Peninsula (AQAP)                                       889
# Tehrik-i-Taliban Pakistan (TTP)                                                799
# Donetsk People's Republic                                                      624
# ...

# %% [markdown]
# - The 'Taliiban' and 'Islamic State of Iraq and the Levant (ISIL)' have made most attacks in the years [2012 >> 2017] with high cases of kills and injuries

# %%
# ok let's make the same pivot table but with the new dataset for the highest cases years 2012 >> 2017  

high_cases_years.pivot_table(values='Cases', index=['Year','Region','Country' , 'City','Group', 'Attack_Type', 'Target_Type', 'Target']).sort_values('Cases', ascending=False).head(30)
# Out:
#                                                                                                                                                                                                                                       Cases
# Year Region                     Country       City          Group                                              Attack_Type                         Target_Type                    Target
# 2017 North America              United States Las Vegas     Anti-Government extremists                         Armed Assault                       Business                       Security Guard: Jesus Campos                        910.0
# 2014 Sub-Saharan Africa         South Sudan   Bentiu        Sudan People's Liberation Movement in Oppositio... Hostage Taking (Kidnapping)         Religious Figures/Institutions Mosque                                              687.0
# ...

# %% [markdown]
# - United States has the highest number of cases in one attack in years 2012 >> 2017, an armed assault by Anti-Government extremists Group
# - Most of the regions here are 'Middle east& NorthAfrica' and 'SouthAsia'>> Afghanistan, with Bombing explosion and armed assault
# - At this period of years was the revoloution of the arabic spring which make sence to produces all these cases on these years

# %%
# let's see the most target type in years 2012 >> 2017
target_wise = high_cases_years.groupby('Target_Type')['Cases'].sum().sort_values(ascending=False)
target_wise
# Out:
# Target_Type
# Private Citizens & Property       117507.0
# Military                           79004.0
# Police                             57324.0
# Business                           28539.0
# Government (General)               20426.0
# Religious Figures/Institutions     15456.0
# Terrorists/Non-State Militia        9967.0
# Transportation                      8336.0
# Educational Institution             6216.0
# Government (Diplomatic)             3505.0
# Unknown                             2713.0
# Violent Political Party             2331.0
# Airports & Aircraft                 1390.0
# Journalists & Media                 1127.0
# Utilities                            699.0
# NGO                                  551.0
# Tourists                             333.0
# Maritime                             307.0
# Other                                230.0
# Food or Water Supply                 155.0
# Telecommunication                     51.0
# ...

# %%
target_wise.plot(kind='bar', figsize=(10,8))
plt.title('The most target types that left most casualties for years 2012 to 2017')
plt.ylabel('Casualties Count')
plt.show()
